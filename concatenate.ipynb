# %%
import os
import glob
import pandas as pd

# %%
workdir = 'by-legislature'
title = 'all-interventions.csv'
delimiter = ';'
os.chdir(f'./{workdir}')

# %%
# Get all the file names.
filenames = [i for i in glob.glob('*.csv')]

# Change all "; " for ", " to fix all the CSV files where \
# initative names include a semicolon.
for f in filenames:
    text = open(f"{f}", "r")
    text = ''.join([i for i in text]).replace("; ", ", ")
    x = open(f"{f}","w")
    x.writelines(text)
    x.close()

# Get all files as dataframes in pandas.
files = []
for i in range(0, len(filenames) - 1):
    # print(f'{i}')
    files.append(pd.read_csv(filenames[i], delimiter=delimiter))

# Combine all files.
concatenated = pd.concat(files)

# Export.
concatenated.to_csv(f"../{title}", index=False, encoding='utf-8-sig')

# Check it.
pd.read_csv(f'../{title}')
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# /var/folders/ct/921g5yd903j7f8wh5k85dltr0000gn/T/ipykernel_83580/117993130.py:19: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   files.append(pd.read_csv(filenames[i],
# 6
# 7
# 8
# /var/folders/ct/921g5yd903j7f8wh5k85dltr0000gn/T/ipykernel_83580/117993130.py:19: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   files.append(pd.read_csv(filenames[i],
# 9
# 10
# 11
# 12
# /var/folders/ct/921g5yd903j7f8wh5k85dltr0000gn/T/ipykernel_83580/117993130.py:30: DtypeWarning: Columns (10,11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(f'../{title}.csv')
#         legislatura                                      tipo_agrupado  \
# 0              VIII                                                NaN
# 1              VIII                                                NaN
# 2              VIII                                                NaN
# 3              VIII                                                NaN
# 4              VIII                                                NaN
# ...             ...                                                ...
# 3127535          XI  Comparecencias de otras personalidades en Comi...
# 3127536          XI  Comparecencias de otras personalidades en Comi...
# 3127537          XI  Comparecencias de otras personalidades en Comi...
# 3127538          XI  Comparecencias de otras personalidades en Comi...
# 3127539          XI  Comparecencias de otras personalidades en Comi...
#
#                                        tipo  \
# 0                          Proyecto de ley.
# 1                          Proyecto de ley.
# 2                          Proyecto de ley.
# 3                          Proyecto de ley.
# 4                          Proyecto de ley.
# ...                                     ...
# 3127535  Proposición no de Ley en Comisión.
# 3127536  Proposición no de Ley en Comisión.
# 3127537  Proposición no de Ley en Comisión.
# 3127538  Proposición no de Ley en Comisión.
# 3127539  Proposición no de Ley en Comisión.
#
#                                          objeto_iniciativa numero_expediente  \
# 0        Proyecto de Ley sobre técnicas de reproducción...   121/000039/0000
# 1        Proyecto de Ley por la que se regula el estatu...   121/000040/0000
# 2        Opinión del Ministro de Asuntos Exteriores y d...   180/001302/0000
# 3        Opinión del Gobierno acerca de si las política...   180/001303/0000
# 4        Opinión del Gobierno acerca de si las política...   180/001303/0000
# ...                                                    ...               ...
# 3127535  Proposición no de Ley sobre la ampliación en l...   161/000185/0000
# 3127536  Proposición no de Ley sobre la ampliación en l...   161/000185/0000
# 3127537  Proposición no de Ley sobre la ampliación en l...   161/000185/0000
# 3127538  Proposición no de Ley sobre la ampliación en l...   161/000185/0000
# 3127539  Proposición no de Ley sobre la ampliación en l...   161/000185/0000
#
#                                                autores        nombre_sesion  \
# 0                                             Gobierno                Pleno
# 1                                             Gobierno                Pleno
# 2        Arístegui y San Román, Gustavo Manuel de (GP)                Pleno
# 3                          Moragas Sánchez, Jorge (GP)                Pleno
# 4                          Moragas Sánchez, Jorge (GP)                Pleno
# ...                                                ...                  ...
# 3127535                 Grupo Parlamentario Socialista  Comisión de Defensa
# 3127536                 Grupo Parlamentario Socialista  Comisión de Defensa
# 3127537                 Grupo Parlamentario Socialista  Comisión de Defensa
# 3127538                 Grupo Parlamentario Socialista  Comisión de Defensa
# 3127539                 Grupo Parlamentario Socialista  Comisión de Defensa
#
#               fecha                         fase  \
# 0        11/05/2006  Enmiendas o veto del Senado
# 1        11/05/2006  Enmiendas o veto del Senado
# 2        10/05/2006        Pregunta-contestación
# 3        10/05/2006        Pregunta-contestación
# 4        10/05/2006        Pregunta-contestación
# ...             ...                          ...
# 3127535  20/04/2016                       Debate
# 3127536  20/04/2016                       Debate
# 3127537  20/04/2016                       Debate
# 3127538  20/04/2016                       Debate
# 3127539  20/04/2016                       Debate
#
#                                              orador hora_inicio  hora_fin  \
# 0                   Mardones Sevilla, Luis (GCC-NC)         NaN       NaN
# 1                    Cerdà Argent, Agustí (GER-ERC)         NaN       NaN
# 2              Moratinos Cuyaubé, Miguel Ángel (GS)         NaN       NaN
# 3                       Moragas Sánchez, Jorge (GP)         NaN       NaN
# 4              Moratinos Cuyaubé, Miguel Ángel (GS)         NaN       NaN
# ...                                             ...         ...       ...
# 3127535           Cano Leal, Francisco Javier (GCs)    12:46:30  12:49:06
# 3127536      Delgado Ramos, Juan Antonio (GP-EC-EM)    12:49:11  12:54:31
# 3127537  Salvador Armendáriz, Carlos Casimiro (GMx)    12:54:45  12:56:14
# 3127538           Nogueras i Camero, Míriam (GC-DL)    12:56:20  12:56:51
# 3127539                  Tarno Blanco, Ricardo (GP)    12:57:01  13:03:34
#
#                                enlace_emision  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 3127535  https://app.congreso.es/v1/11585203I
# 3127536  https://app.congreso.es/v1/11585207I
# 3127537  https://app.congreso.es/v1/11585208I
# 3127538  https://app.congreso.es/v1/11585209I
# 3127539  https://app.congreso.es/v1/11585210I
#
#                                            enlace_descarga  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 3127535  https://www.congreso.es:443https://static.cong...
# 3127536  https://www.congreso.es:443https://static.cong...
# 3127537  https://www.congreso.es:443https://static.cong...
# 3127538  https://www.congreso.es:443https://static.cong...
# 3127539  https://www.congreso.es:443https://static.cong...
#
#                                                 enlace_pdf
# 0        https://www.congreso.es:443/public_oficiales/L...
# 1        https://www.congreso.es:443/public_oficiales/L...
# 2        https://www.congreso.es:443/public_oficiales/L...
# 3        https://www.congreso.es:443/public_oficiales/L...
# 4        https://www.congreso.es:443/public_oficiales/L...
# ...                                                    ...
# 3127535  https://www.congreso.es:443/public_oficiales/L...
# 3127536  https://www.congreso.es:443/public_oficiales/L...
# 3127537  https://www.congreso.es:443/public_oficiales/L...
# 3127538  https://www.congreso.es:443/public_oficiales/L...
# 3127539  https://www.congreso.es:443/public_oficiales/L...
#
# [3127540 rows x 15 columns]
